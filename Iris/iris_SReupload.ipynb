# %% [markdown]
# # Classificação Quântica do Dataset Iris - Sem Data Re-uploading
#
# Este notebook implementa um classificador quântico variacional (VQC) para o dataset Iris **sem** a técnica de Data Re-uploading. Os dados são encodados apenas uma vez no início do circuito.
#
# ## Importação das Bibliotecas

# %%
import pennylane as qml
import pennylane.numpy as np
import torch
import torch.nn as nn
from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.metrics import confusion_matrix
from tqdm import tqdm
import matplotlib.pyplot as plt

# %% [markdown]
# ### Configuração do Modelo e Estrutura Quântica
# Para o dataset Iris, ainda foi preciso de um circuito mais completo, com mais qubits, layers, nesse notebook eu não usei o reupload para treinamento
#
# Por ser um problema multiclasse, resolvi fazer de uma forma diferente o modelo ele é treinado com 3 "classificadores". Na verdade parte do seu peso é treinado especificamente para algum dos resultados, ou seja, o w[1] fica com o primeiro dado, w[2] com o segundo, etc...
# Com isso, achei que seria mais facil utilizar o pytoch para treinamento pois ele consegue mapear esses pesos de melhor forma, o que otimizou meu tempo para evitar que escrevesse linhas e linhas de codigos para poder fazer a loss funcionar de forma correta
#
# #### Predictor
# - Ponto importante desse problema é que no predictor eu passo pelos pesos procurando especificamente a saida deles, com o conjunto de 3 saidas eu pego a maior e digo como resposta ela

# %%
X, y = load_iris(return_X_y=True)
data = load_iris()
X = data.data
y = data.target

scaler = MinMaxScaler()
scaler.fit(X)
X_norm = scaler.transform(X)

X_torch = torch.tensor(X_norm, dtype=torch.float32, requires_grad=False)
y_torch = torch.tensor(y, dtype=torch.long, requires_grad=False)
X_train, X_val, y_train, y_val = train_test_split(
    X_torch, y_torch, test_size=0.2, random_state=42, shuffle=True
)

# %% [markdown]
# ## Configuração do Modelo Quântico
#
# Parâmetros do circuito:
# - **4 qubits**: Um para cada feature do dataset
# - **8 camadas**: Profundidade do circuito variacional
# - **3 classes**: Correspondendo às 3 espécies de Iris
#
# Os pesos são organizados em formato `(n_classes, n_layers, n_qubits, 3)` para permitir treinamento separado por classe.

# %% [markdown]
# ## Carregamento e Pré-processamento dos Dados
#
# O dataset Iris contém 150 amostras de 3 espécies de flores (Setosa, Versicolor, Virginica), cada uma com 4 features (comprimento e largura de sépalas e pétalas). Os dados são normalizados usando `MinMaxScaler` para adequar ao encoding quântico.

# %%
n_qubits = 4
n_layers = 8
n_classes = 3
shape_weights = (n_classes, n_layers, n_qubits, 3)
weights_data = 2 * np.pi * torch.rand(shape_weights)
weights = weights_data.clone().detach().requires_grad_(True)
bias = torch.zeros(n_classes, requires_grad=True)
dev = qml.device("default.qubit", wires=n_qubits)

# %%
opt = torch.optim.Adam([weights, bias], lr=0.04)
loss_fn = nn.CrossEntropyLoss()

# %% [markdown]
# ## Definição do Otimizador e Função de Perda
#
# Utilizamos o otimizador Adam com learning rate de 0.04 e CrossEntropyLoss para classificação multiclasse.

# %% [markdown]
# ### Circuito Quântico e Estratégia de Embedding
# Conforme observado na implementação abaixo, o `AngleEmbedding` não é inserido dentro do loop de camadas do circuito, para retirar o reupload
# #### Predictor
# - Ponto importante desse problema é que no predictor eu passo pelos pesos procurando especificamente a saida deles, com o conjunto de 3 saidas eu pego a maior e digo como resposta ela

# %%
@qml.qnode(dev, interface="torch")
def circuito(weights, x):
    qml.AngleEmbedding(features=x, wires=range(n_qubits), rotation="Z")
    for i, layer_w in enumerate(weights):
        w_expandido = qml.math.expand_dims(layer_w, 0)
        qml.StronglyEntanglingLayers(weights=w_expandido, wires=range(n_qubits))

    return qml.expval(qml.PauliZ(0))

# %%
def predictor(weights, bias, x):
    res = []
    for i in range(3):
        output = circuito(weights[i], x) + bias[i]
        res.append(output)

    return torch.stack(res).t()

# %% [markdown]
# # Visualização do circuito

# %%
w_sample = weights[0]
x_sample = X_train[0]

fig, ax = qml.draw_mpl(circuito, decimals=2)(w_sample, x_sample)
plt.show()

# %% [markdown]
# # Treino

# %%
loss_history = []
acc_history = []
epochs_x = []

epochs = 5000
batch_size = 120

X_val_torch = X_val.clone().detach().to(torch.float32)
y_val_torch = y_val.clone().detach().to(torch.long)
X_train_torch = X_train.clone().detach().to(torch.float32)
y_train_torch = y_train.clone().detach().to(torch.long)

pbar = tqdm(range(epochs), desc="Treinando")

for it in pbar:
    opt.zero_grad()

    batch_index = torch.randint(0, len(X_train_torch), (batch_size,))
    X_batch = X_train_torch[batch_index]
    y_batch = y_train_torch[batch_index]

    outputs = predictor(weights, bias, X_batch)
    loss = loss_fn(outputs, y_batch)
    loss.backward()
    opt.step()

    loss_history.append(loss.item())

    if it % 10 == 0:
        with torch.no_grad():
            outputs_val = predictor(weights, bias, X_torch)
            predictions = torch.argmax(outputs_val, dim=1)
            correct = (predictions == y_torch).float().sum()
            current_acc = correct / len(y_torch)

            acc_history.append(current_acc.item())
            epochs_x.append(it)
            last_acc = current_acc.item()

    pbar.set_postfix(loss=f"{loss.item():.4f}", acc=f"{last_acc:.4f}")

pbar.close()

plt.style.use('seaborn-v0_8')
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

ax1.plot(range(len(loss_history)), loss_history, label='Training Loss', color='tab:blue', alpha=0.7)
ax1.set_title('Convergência do Custo')
ax1.set_xlabel('Iterações Realizadas')  # Texto ajustado
ax1.set_ylabel('Custo')
ax1.grid(True)
ax1.legend()

ax2.plot(epochs_x, acc_history, label='Validation Accuracy', color='tab:green', marker='o', linestyle='-')
ax2.set_title('Evolução da Acurácia')
ax2.set_xlabel('Épocas')
ax2.set_ylabel('Acurácia')
ax2.set_ylim(0, 1.05)
ax2.grid(True)
ax2.legend()

plt.tight_layout()
plt.show()
# Out:
# Treinando: 100%|██████████| 5000/5000 [17:04<00:00,  4.88it/s, acc=0.3333, loss=1.1045]

# %%
plt.tight_layout()
plt.show()

def val(xx, yy):
    class_names = ["Setosa (0)", "Versicolor (1)", "Virginica (2)"]

    print("\n--- INICIANDO VALIDAÇÃO ---\n")
    with torch.no_grad():
        logits = predictor(weights, bias, xx)

        predictions = torch.argmax(logits, dim=1)

    results = []
    correct_count = 0

    print(f"{'ID':<5} | {'Real':<15} | {'Predito':<15} | {'Status'}")
    print("-" * 50)

    for i in range(len(yy)):
        real_idx = yy[i].item()
        pred_idx = predictions[i].item()

        is_correct = real_idx == pred_idx
        if is_correct:
            correct_count += 1
            status = "OK"
        else:
            status = "ERRO"

        print(f"{i:<5} | {class_names[real_idx]:<15} | {class_names[pred_idx]:<15} | {status}")

        results.append({
            "Real": real_idx,
            "Predito": pred_idx,
            "Correto": is_correct
        })

    final_acc = correct_count / len(yy)
    print("-" * 50)
    print(f"Total de Amostras: {len(yy)}")
    print(f"Acertos: {correct_count}")
    print(f"Acurácia Final: {final_acc:.2%}")

    plt.figure(figsize=(6, 5))
    cm = confusion_matrix(y_torch.numpy(), predictions.numpy())

    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predito')
    plt.ylabel('Real')
    plt.title('Matriz de Confusão')
    plt.show()

# %% [markdown]
# ## Validação e Matriz de Confusão
#
# Função para avaliar o modelo e visualizar os resultados através da matriz de confusão.

# %%
val(X_torch, y_torch)
# Out:
# --- INICIANDO VALIDAÇÃO ---
#
# ID    | Real            | Predito         | Status
# --------------------------------------------------
# 0     | Setosa (0)      | Virginica (2)   | ERRO
# 1     | Setosa (0)      | Virginica (2)   | ERRO
# 2     | Setosa (0)      | Virginica (2)   | ERRO
# 3     | Setosa (0)      | Virginica (2)   | ERRO
# 4     | Setosa (0)      | Virginica (2)   | ERRO
# 5     | Setosa (0)      | Virginica (2)   | ERRO
# 6     | Setosa (0)      | Virginica (2)   | ERRO
# 7     | Setosa (0)      | Virginica (2)   | ERRO
# 8     | Setosa (0)      | Virginica (2)   | ERRO
# 9     | Setosa (0)      | Virginica (2)   | ERRO
# 10    | Setosa (0)      | Virginica (2)   | ERRO
# 11    | Setosa (0)      | Virginica (2)   | ERRO
# 12    | Setosa (0)      | Virginica (2)   | ERRO
# 13    | Setosa (0)      | Virginica (2)   | ERRO
# 14    | Setosa (0)      | Virginica (2)   | ERRO
# 15    | Setosa (0)      | Virginica (2)   | ERRO
# 16    | Setosa (0)      | Virginica (2)   | ERRO
# 17    | Setosa (0)      | Virginica (2)   | ERRO
# 18    | Setosa (0)      | Virginica (2)   | ERRO
# 19    | Setosa (0)      | Virginica (2)   | ERRO
# 20    | Setosa (0)      | Virginica (2)   | ERRO
# 21    | Setosa (0)      | Virginica (2)   | ERRO
# 22    | Setosa (0)      | Virginica (2)   | ERRO
# 23    | Setosa (0)      | Virginica (2)   | ERRO
# 24    | Setosa (0)      | Virginica (2)   | ERRO
# 25    | Setosa (0)      | Virginica (2)   | ERRO
# 26    | Setosa (0)      | Virginica (2)   | ERRO
# 27    | Setosa (0)      | Virginica (2)   | ERRO
# 28    | Setosa (0)      | Virginica (2)   | ERRO
# 29    | Setosa (0)      | Virginica (2)   | ERRO
# 30    | Setosa (0)      | Virginica (2)   | ERRO
# 31    | Setosa (0)      | Virginica (2)   | ERRO
# 32    | Setosa (0)      | Virginica (2)   | ERRO
# 33    | Setosa (0)      | Virginica (2)   | ERRO
# 34    | Setosa (0)      | Virginica (2)   | ERRO
# 35    | Setosa (0)      | Virginica (2)   | ERRO
# 36    | Setosa (0)      | Virginica (2)   | ERRO
# 37    | Setosa (0)      | Virginica (2)   | ERRO
# 38    | Setosa (0)      | Virginica (2)   | ERRO
# 39    | Setosa (0)      | Virginica (2)   | ERRO
# 40    | Setosa (0)      | Virginica (2)   | ERRO
# 41    | Setosa (0)      | Virginica (2)   | ERRO
# 42    | Setosa (0)      | Virginica (2)   | ERRO
# 43    | Setosa (0)      | Virginica (2)   | ERRO
# 44    | Setosa (0)      | Virginica (2)   | ERRO
# 45    | Setosa (0)      | Virginica (2)   | ERRO
# 46    | Setosa (0)      | Virginica (2)   | ERRO
# 47    | Setosa (0)      | Virginica (2)   | ERRO
# 48    | Setosa (0)      | Virginica (2)   | ERRO
# 49    | Setosa (0)      | Virginica (2)   | ERRO
# 50    | Versicolor (1)  | Virginica (2)   | ERRO
# 51    | Versicolor (1)  | Virginica (2)   | ERRO
# 52    | Versicolor (1)  | Virginica (2)   | ERRO
# 53    | Versicolor (1)  | Virginica (2)   | ERRO
# 54    | Versicolor (1)  | Virginica (2)   | ERRO
# 55    | Versicolor (1)  | Virginica (2)   | ERRO
# 56    | Versicolor (1)  | Virginica (2)   | ERRO
# 57    | Versicolor (1)  | Virginica (2)   | ERRO
# 58    | Versicolor (1)  | Virginica (2)   | ERRO
# 59    | Versicolor (1)  | Virginica (2)   | ERRO
# 60    | Versicolor (1)  | Virginica (2)   | ERRO
# 61    | Versicolor (1)  | Virginica (2)   | ERRO
# 62    | Versicolor (1)  | Virginica (2)   | ERRO
# 63    | Versicolor (1)  | Virginica (2)   | ERRO
# 64    | Versicolor (1)  | Virginica (2)   | ERRO
# 65    | Versicolor (1)  | Virginica (2)   | ERRO
# 66    | Versicolor (1)  | Virginica (2)   | ERRO
# 67    | Versicolor (1)  | Virginica (2)   | ERRO
# 68    | Versicolor (1)  | Virginica (2)   | ERRO
# 69    | Versicolor (1)  | Virginica (2)   | ERRO
# 70    | Versicolor (1)  | Virginica (2)   | ERRO
# 71    | Versicolor (1)  | Virginica (2)   | ERRO
# 72    | Versicolor (1)  | Virginica (2)   | ERRO
# 73    | Versicolor (1)  | Virginica (2)   | ERRO
# 74    | Versicolor (1)  | Virginica (2)   | ERRO
# 75    | Versicolor (1)  | Virginica (2)   | ERRO
# 76    | Versicolor (1)  | Virginica (2)   | ERRO
# 77    | Versicolor (1)  | Virginica (2)   | ERRO
# 78    | Versicolor (1)  | Virginica (2)   | ERRO
# 79    | Versicolor (1)  | Virginica (2)   | ERRO
# 80    | Versicolor (1)  | Virginica (2)   | ERRO
# 81    | Versicolor (1)  | Virginica (2)   | ERRO
# 82    | Versicolor (1)  | Virginica (2)   | ERRO
# 83    | Versicolor (1)  | Virginica (2)   | ERRO
# 84    | Versicolor (1)  | Virginica (2)   | ERRO
# 85    | Versicolor (1)  | Virginica (2)   | ERRO
# 86    | Versicolor (1)  | Virginica (2)   | ERRO
# 87    | Versicolor (1)  | Virginica (2)   | ERRO
# 88    | Versicolor (1)  | Virginica (2)   | ERRO
# 89    | Versicolor (1)  | Virginica (2)   | ERRO
# 90    | Versicolor (1)  | Virginica (2)   | ERRO
# 91    | Versicolor (1)  | Virginica (2)   | ERRO
# 92    | Versicolor (1)  | Virginica (2)   | ERRO
# 93    | Versicolor (1)  | Virginica (2)   | ERRO
# 94    | Versicolor (1)  | Virginica (2)   | ERRO
# 95    | Versicolor (1)  | Virginica (2)   | ERRO
# 96    | Versicolor (1)  | Virginica (2)   | ERRO
# 97    | Versicolor (1)  | Virginica (2)   | ERRO
# 98    | Versicolor (1)  | Virginica (2)   | ERRO
# 99    | Versicolor (1)  | Virginica (2)   | ERRO
# 100   | Virginica (2)   | Virginica (2)   | OK
# 101   | Virginica (2)   | Virginica (2)   | OK
# 102   | Virginica (2)   | Virginica (2)   | OK
# 103   | Virginica (2)   | Virginica (2)   | OK
# 104   | Virginica (2)   | Virginica (2)   | OK
# 105   | Virginica (2)   | Virginica (2)   | OK
# 106   | Virginica (2)   | Virginica (2)   | OK
# 107   | Virginica (2)   | Virginica (2)   | OK
# 108   | Virginica (2)   | Virginica (2)   | OK
# 109   | Virginica (2)   | Virginica (2)   | OK
# 110   | Virginica (2)   | Virginica (2)   | OK
# 111   | Virginica (2)   | Virginica (2)   | OK
# 112   | Virginica (2)   | Virginica (2)   | OK
# 113   | Virginica (2)   | Virginica (2)   | OK
# 114   | Virginica (2)   | Virginica (2)   | OK
# 115   | Virginica (2)   | Virginica (2)   | OK
# 116   | Virginica (2)   | Virginica (2)   | OK
# 117   | Virginica (2)   | Virginica (2)   | OK
# 118   | Virginica (2)   | Virginica (2)   | OK
# 119   | Virginica (2)   | Virginica (2)   | OK
# 120   | Virginica (2)   | Virginica (2)   | OK
# 121   | Virginica (2)   | Virginica (2)   | OK
# 122   | Virginica (2)   | Virginica (2)   | OK
# 123   | Virginica (2)   | Virginica (2)   | OK
# 124   | Virginica (2)   | Virginica (2)   | OK
# 125   | Virginica (2)   | Virginica (2)   | OK
# 126   | Virginica (2)   | Virginica (2)   | OK
# 127   | Virginica (2)   | Virginica (2)   | OK
# 128   | Virginica (2)   | Virginica (2)   | OK
# 129   | Virginica (2)   | Virginica (2)   | OK
# 130   | Virginica (2)   | Virginica (2)   | OK
# 131   | Virginica (2)   | Virginica (2)   | OK
# 132   | Virginica (2)   | Virginica (2)   | OK
# 133   | Virginica (2)   | Virginica (2)   | OK
# 134   | Virginica (2)   | Virginica (2)   | OK
# 135   | Virginica (2)   | Virginica (2)   | OK
# 136   | Virginica (2)   | Virginica (2)   | OK
# 137   | Virginica (2)   | Virginica (2)   | OK
# 138   | Virginica (2)   | Virginica (2)   | OK
# 139   | Virginica (2)   | Virginica (2)   | OK
# 140   | Virginica (2)   | Virginica (2)   | OK
# 141   | Virginica (2)   | Virginica (2)   | OK
# 142   | Virginica (2)   | Virginica (2)   | OK
# 143   | Virginica (2)   | Virginica (2)   | OK
# 144   | Virginica (2)   | Virginica (2)   | OK
# 145   | Virginica (2)   | Virginica (2)   | OK
# 146   | Virginica (2)   | Virginica (2)   | OK
# 147   | Virginica (2)   | Virginica (2)   | OK
# 148   | Virginica (2)   | Virginica (2)   | OK
# 149   | Virginica (2)   | Virginica (2)   | OK
# --------------------------------------------------
# Total de Amostras: 150
# Acertos: 50
# Acurácia Final: 33.33%

# %% [markdown]
# ### Validação no Dataset Completo

# %%
val(X_val_torch, y_val_torch)
# Out:
# --- INICIANDO VALIDAÇÃO ---
#
# ID    | Real            | Predito         | Status
# --------------------------------------------------
# 0     | Versicolor (1)  | Virginica (2)   | ERRO
# 1     | Setosa (0)      | Virginica (2)   | ERRO
# 2     | Virginica (2)   | Virginica (2)   | OK
# 3     | Versicolor (1)  | Virginica (2)   | ERRO
# 4     | Versicolor (1)  | Virginica (2)   | ERRO
# 5     | Setosa (0)      | Virginica (2)   | ERRO
# 6     | Versicolor (1)  | Virginica (2)   | ERRO
# 7     | Virginica (2)   | Virginica (2)   | OK
# 8     | Versicolor (1)  | Virginica (2)   | ERRO
# 9     | Versicolor (1)  | Virginica (2)   | ERRO
# 10    | Virginica (2)   | Virginica (2)   | OK
# 11    | Setosa (0)      | Virginica (2)   | ERRO
# 12    | Setosa (0)      | Virginica (2)   | ERRO
# 13    | Setosa (0)      | Virginica (2)   | ERRO
# 14    | Setosa (0)      | Virginica (2)   | ERRO
# 15    | Versicolor (1)  | Virginica (2)   | ERRO
# 16    | Virginica (2)   | Virginica (2)   | OK
# 17    | Versicolor (1)  | Virginica (2)   | ERRO
# 18    | Versicolor (1)  | Virginica (2)   | ERRO
# 19    | Virginica (2)   | Virginica (2)   | OK
# 20    | Setosa (0)      | Virginica (2)   | ERRO
# 21    | Virginica (2)   | Virginica (2)   | OK
# 22    | Setosa (0)      | Virginica (2)   | ERRO
# 23    | Virginica (2)   | Virginica (2)   | OK
# 24    | Virginica (2)   | Virginica (2)   | OK
# 25    | Virginica (2)   | Virginica (2)   | OK
# 26    | Virginica (2)   | Virginica (2)   | OK
# 27    | Virginica (2)   | Virginica (2)   | OK
# 28    | Setosa (0)      | Virginica (2)   | ERRO
# 29    | Setosa (0)      | Virginica (2)   | ERRO
# --------------------------------------------------
# Total de Amostras: 30
# Acertos: 11
# Acurácia Final: 36.67%
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 val(X_val_torch, y_val_torch)
#
# Cell In[9], line 45, in val(xx, yy)
#      42 print(f"Acurácia Final: {final_acc:.2%}")
#      44 plt.figure(figsize=(6, 5))
# ---> 45 cm = confusion_matrix(y_torch.numpy(), predictions.numpy())
#      47 sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
#      48             xticklabels=class_names, yticklabels=class_names)
#      49 plt.xlabel('Predito')
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:549, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     546     sample_weight = _convert_to_numpy(sample_weight, xp)
#     548 if len(sample_weight) > 0:
# --> 549     y_type, y_true, y_pred, sample_weight = _check_targets(
#     550         y_true, y_pred, sample_weight
#     551     )
#     552 else:
#     553     # This is needed to handle the special case where y_true, y_pred and
#     554     # sample_weight are all empty.
#     555     # In this case we don't pass sample_weight to _check_targets that would
#     556     # check that sample_weight is not empty and we don't reuse the returned
#     557     # sample_weight
#     558     y_type, y_true, y_pred, _ = _check_targets(y_true, y_pred)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\metrics\_classification.py:108, in _check_targets(y_true, y_pred, sample_weight)
#      77 """Check that y_true and y_pred belong to the same classification task.
#      78
#      79 This converts multiclass or binary types to a common shape, and raises a
#    (...)    105 sample_weight : array or None
#     106 """
#     107 xp, _ = get_namespace(y_true, y_pred, sample_weight)
# --> 108 check_consistent_length(y_true, y_pred, sample_weight)
#     109 type_true = type_of_target(y_true, input_name="y_true")
#     110 type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:464, in check_consistent_length(*arrays)
#     462 lengths = [_num_samples(X) for X in arrays if X is not None]
#     463 if len(set(lengths)) > 1:
# --> 464     raise ValueError(
#     465         "Found input variables with inconsistent numbers of samples: %r"
#     466         % [int(l) for l in lengths]
#     467     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [150, 30, 150]

# %% [markdown]
# ### Validação no Conjunto de Teste
#
# Avaliação apenas nos dados de teste (20% do dataset) que não foram vistos durante o treinamento.
